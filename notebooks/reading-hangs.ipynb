# %%
# !pip install --quiet climetlab

# %%
import climetlab as cml
source = cml.load_source(
    "cds",
    "reanalysis-era5-single-levels",
    variable=["2t", "msl"],
    product_type="reanalysis",
    area=[50, -50, 20, 50],
    date="2012-12-12",
    time="12:00",
)

# %%
ds = source.to_xarray(); ds
# Out:
# <xarray.Dataset>
# Dimensions:     (number: 1, time: 1, step: 1, surface: 1, latitude: 121, longitude: 401)
# Coordinates:
#   * number      (number) int64 0
#   * time        (time) datetime64[ns] 2012-12-12T12:00:00
#   * step        (step) timedelta64[ns] 00:00:00
#   * surface     (surface) float64 0.0
#   * latitude    (latitude) float64 50.0 49.75 49.5 49.25 ... 20.5 20.25 20.0
#   * longitude   (longitude) float64 -50.0 -49.75 -49.5 ... 49.5 49.75 50.0
#     valid_time  (time, step) datetime64[ns] dask.array<chunksize=(1, 1), meta=np.ndarray>
# Data variables:
#     t2m         (number, time, step, surface, latitude, longitude) float32 dask.array<chunksize=(1, 1, 1, 1, 121, 401), meta=np.ndarray>
#     msl         (number, time, step, surface, latitude, longitude) float32 dask.array<chunksize=(1, 1, 1, 1, 121, 401), meta=np.ndarray>
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
# ...
